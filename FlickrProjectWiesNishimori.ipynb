# %% [markdown]
# # The following notebook shows the Flickr api GIS project created by Nathan Wies and Kazuto Nishimori
# ## The aim of this code is to find interesting trends in spatial Flickr data

# %%
"""
Code written by Nathan Wies and Kazuto Nishimori
1/11/20
"""

#Initialize api

import USERAUTH
import flickr_api
from flickr_api.api import flickr
import geopandas as gpd
import pandas as pd
import json
import numpy as np

# %% [markdown]
# ### Using the search method to pull data
# #### Link to method documentation: https://www.flickr.com/services/api/flickr.photos.search.html
#
# #### There is a pretty extensive list of spatial methods by which one can look up data which generally includes most parameters you could think of. All of these are posted at the link above.
#
#
# ##### bbox -
# A comma-delimited list of 4 values defining the Bounding Box of the area that will be searched.
#
# The 4 values represent the bottom-left corner of the box and the top-right corner, minimum_longitude, minimum_latitude, maximum_longitude, maximum_latitude.

# %%
paris_pictures_json = flickr.photos.search(privacy_filter = 1, accuracy = 16, lat=48.857765, lon = 2.295672, radius = .005, format= "json", nojsoncallback = 1)
parispics = json.loads(paris_pictures_json)
print("The total number of pictures found within 5 km of the center of Paris is",
    parispics["photos"]["total"])
print(parispics)
# Out:
# The total number of pictures found within 5 km of the center of Paris is 56
# {'photos': {'page': 1, 'pages': 1, 'perpage': 250, 'total': '56', 'photo': [{'id': '37328053084', 'owner': '17993950@N00', 'secret': '2484e22b1f', 'server': '4460', 'farm': 5, 'title': 'IMG_7035', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '33100036401', 'owner': '24827377@N00', 'secret': '15fb045ceb', 'server': '730', 'farm': 1, 'title': 'Dancing and singing Gospel songs', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '22758831916', 'owner': '33531758@N03', 'secret': 'f9c1e274b3', 'server': '5626', 'farm': 6, 'title': 'Panorámica de Paris, 2', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '22354010651', 'owner': '30150883@N04', 'secret': '9862635c55', 'server': '566', 'farm': 1, 'title': '', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '21205122724', 'owner': '35729004@N02', 'secret': 'e8a8c1e43a', 'server': '710', 'farm': 1, 'title': 'IMG_3230', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '20403119402', 'owner': '32490376@N08', 'secret': '92d8fd77b1', 'server': '338', 'farm': 1, 'title': 'United Buddy Bears', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '19348765729', 'owner': '22583315@N08', 'secret': 'a351d81b88', 'server': '464', 'farm': 1, 'title': '', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '18914390943', 'owner': '22583315@N08', 'secret': '522277c1ed', 'server': '3814', 'farm': 4, 'title': '', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '17145940875', 'owner': '63811125@N07', 'secret': '9afb4f5669', 'server': '7590', 'farm': 8, 'title': 'IMG_2194', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '14583404879', 'owner': '52486375@N03', 'secret': '8496426854', 'server': '5594', 'farm': 6, 'title': 'Champ de Mars', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '14020080045', 'owner': '80458164@N07', 'secret': 'eb95a56824', 'server': '7298', 'farm': 8, 'title': '2014-01-24 14.03.18', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '13070548824', 'owner': '89210046@N08', 'secret': '3c48ce791d', 'server': '3418', 'farm': 4, 'title': '', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '11457045596', 'owner': '67701031@N07', 'secret': '30f821538b', 'server': '7300', 'farm': 8, 'title': '198', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '9725300610', 'owner': '68334186@N08', 'secret': '5f199d197b', 'server': '2834', 'farm': 3, 'title': 'Camera Roll-719', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '9710806441', 'owner': '101473946@N02', 'secret': 'f106f25260', 'server': '2888', 'farm': 3, 'title': '歐洲之旅-法國巴黎(巴黎鐵塔夜景)', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '9524730276', 'owner': '98523107@N06', 'secret': 'acf6192d51', 'server': '5500', 'farm': 6, 'title': '', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '9521922223', 'owner': '98523107@N06', 'secret': 'd732d09a7a', 'server': '3779', 'farm': 4, 'title': '', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '9130648416', 'owner': '91276263@N06', 'secret': '9c3d18479d', 'server': '5465', 'farm': 6, 'title': 'Paris (103 of 316)', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '8898898407', 'owner': '56623901@N00', 'secret': 'f5fe1758de', 'server': '7385', 'farm': 8, 'title': 'IMG_2163', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '8703876708', 'owner': '95335660@N03', 'secret': '41631b6081', 'server': '8543', 'farm': 9, 'title': 'IMG_0572', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '8430849435', 'owner': '87431919@N03', 'secret': '6182f2ecfb', 'server': '8329', 'farm': 9, 'title': "Paris'013", 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '8230075643', 'owner': '64298058@N04', 'secret': 'd7cd066c4d', 'server': '8480', 'farm': 9, 'title': 'Paris - Raven', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '7867930982', 'owner': '40067478@N00', 'secret': 'a099d0d143', 'server': '8290', 'farm': 9, 'title': 'a really big cell phone tower.  AKA- Eiffel Tower', 'ispublic': 1, 'isfriend': 0, 'isfamily': 0}, {'id': '76921 ...

# %%
paris_pictures_json = flickr.photos.search(privacy_filter = 1, accuracy = 16, lat=48.857765, lon = 2.295672, radius = .005, format= "json", nojsoncallback = 1)
parispics = json.loads(paris_pictures_json)

# %%
def findpicturefreq(lonmin, lonmax, latmin, latmax, size):
    df = pd.DataFrame(columns =["Latitude", "Longitude", "Total Pictures"])
    X = np.linspace(latmin, latmax, num=3)
    Y =  np.linspace(lonmin, lonmax, num=3)
    xv, yv = np.meshgrid(X, Y, sparse=False)
    print(np.shape(xv))
    for i in range(size):
        for j in range(size):
            print(xv[i][j])
            print(yv[i][j])
    return xv, yv

findpicturefreq(2.282772, 2.322956,48.861748, 48.886598, 3)
# Out:
# (3, 3)
# 48.861748
# 2.282772
# 48.874173
# 2.282772
# 48.886598
# 2.282772
# 48.861748
# 2.302864
# 48.874173
# 2.302864
# 48.886598
# 2.302864
# 48.861748
# 2.322956
# 48.874173
# 2.322956
# 48.886598
# 2.322956

# %%
paris_pictures_json
# Out:
# b'{"photos":{"page":1,"pages":1,"perpage":250,"total":"11","photo":[{"id":"42729146421","owner":"139132001@N03","secret":"b8746cbc11","server":"1723","farm":2,"title":"Portrait of Maria Eleonora of Brandenburg (Konigsberg, 1599-Stockholm, 1655)","ispublic":1,"isfriend":0,"isfamily":0},{"id":"17073504","owner":"46769392@N00","secret":"e0c6ae13f1","server":"11","farm":1,"title":"tour eiffel","ispublic":1,"isfriend":0,"isfamily":0},{"id":"26340025028","owner":"136515480@N04","secret":"3e692feedb","server":"4620","farm":5,"title":"La D\\u00e9fense sous la neige","ispublic":1,"isfriend":0,"isfamily":0},{"id":"39314707365","owner":"136515480@N04","secret":"b896887ee4","server":"4715","farm":5,"title":"La D\\u00e9fense sous la neige","ispublic":1,"isfriend":0,"isfamily":0},{"id":"39501071934","owner":"136515480@N04","secret":"018c834768","server":"4702","farm":5,"title":"La D\\u00e9fense sous la neige","ispublic":1,"isfriend":0,"isfamily":0},{"id":"26340021028","owner":"136515480@N04","secret":"6ec66efbe2","server":"4710","farm":5,"title":"La D\\u00e9fense sous la neige","ispublic":1,"isfriend":0,"isfamily":0},{"id":"25341303367","owner":"136515480@N04","secret":"d188c287b3","server":"4741","farm":5,"title":"La D\\u00e9fense sous la neige","ispublic":1,"isfriend":0,"isfamily":0},{"id":"40212425591","owner":"136515480@N04","secret":"fa098f831c","server":"4748","farm":5,"title":"La D\\u00e9fense sous la neige","ispublic":1,"isfriend":0,"isfamily":0},{"id":"25341297767","owner":"136515480@N04","secret":"f2bde59809","server":"4624","farm":5,"title":"La D\\u00e9fense sous la neige","ispublic":1,"isfriend":0,"isfamily":0},{"id":"40212373491","owner":"136515480@N04","secret":"2bb104aaf6","server":"4764","farm":5,"title":"La D\\u00e9fense sous la neige","ispublic":1,"isfriend":0,"isfamily":0},{"id":"19561709891","owner":"131087023@N05","secret":"21b4755d8f","server":"428","farm":1,"title":"Flamme gave life to humain. But on this picture, flamme is totally pointless...","ispublic":1,"isfriend":0,"isfamily":0}]},"stat":"ok"}'

# %% [markdown]
# ## Creating Dataframe from pulled data (parsing as json file)

# %%
"""
This method pulls data from the previous list. Unfortunatly this list is really long
so we NEED to check how many pings are acceptable or if there is a way to pull all of 
this data at once instead of sequentially, and if there is a limit to how much data 
we can pull per day.
"""
def create_df(pics):

    df = pd.DataFrame(columns =['id','latitude', 'longitude', 'accuracy', 'context', 'locality', 'county', 'region', 'country', 
                              'neighbourhood','title', "owner"])
    i=0
    for pic in pics["photos"]["photo"]:
        newfile = json.loads(flickr.photos.geo.getLocation(photo_id = pic["id"], format= "json", nojsoncallback = 1))
        df.loc[len(df)] = parse_json_data(newfile, pic["title"], pic["owner"])
        
        i+=1
        if(i>4):
            return df


def parse_json_data(output, title, owner):
    values = []
    output = output['photo']
    values.append(output['id'])
    output = output['location']
    values.append(output['latitude'])
    values.append(output['longitude'])
    values.append(output['accuracy'])
    values.append(output['context'])
    try:
        values.append(output['locality']['_content'])
    except:
        values.append("NaN")
    values.append(output['county']['_content'])
    values.append(output['region']['_content'])
    values.append(output['country']['_content'])
    values.append(output['neighbourhood']['_content'])
    values.append(title)
    values.append(owner)
    return values

df = create_df(parispics)
df
# Out:
#              id   latitude longitude accuracy context  \
# 0   49374493921  48.871666  2.378611       16       0
# 1   49374162721  48.886822  2.343059       16       0
# 2   49374322607  48.853252  2.347022       16       0
# 3   49373661968  48.853266  2.347027       16       0
# 4   49374318272  48.852536  2.347975       16       0
# 5   49374189552  48.893664  2.266595       16       0
# 6   49373989221  48.859052  2.338070       16       0
# 7   49373505968  48.853502  2.346958       16       0
# 8   49374102187  48.855394  2.345066       16       0
# 9   49374099122  48.855394  2.345066       16       0
# 10  49373439533  48.855394  2.345066       16       0
#
#                       locality          county         region country  \
# 0                        Paris           Paris  Île-de-France  France
# 1                        Paris           Paris  Île-de-France  France
# 2                          NaN           Paris  Île-de-France  France
# 3                          NaN           Paris  Île-de-France  France
# 4                          NaN           Paris  Île-de-France  France
# 5   Arrondissement de Nanterre  Hauts-de-Seine  Île-de-France  France
# 6                        Paris           Paris  Île-de-France  France
# 7                          NaN           Paris  Île-de-France  France
# 8                        Paris           Paris  Île-de-France  France
# 9                        Paris           Paris  Île-de-France  France
# 10                       Paris           Paris  Île-de-France  France
#
#                                    neighbourhood  \
# 0                                     Belleville
# 1                     Paris 18 Buttes-Montmartre
# 2
# 3
# 4
# 5                              Neuilly-sur-Seine
# 6              Paris 04 Ancien - Quartier Louvre
# 7
# 8   Paris 11 Ancien - Quartier Palais-de-Justice
# 9   Paris 11 Ancien - Quartier Palais-de-Justice
# 10  Paris 11 Ancien - Quartier Palais-de-Justice
#
#                                                 title          owner
# 0                                 2020-01-12_07-57-57   66944824@N05
# 1                                      Combo enflammé   27420180@N08
# 2                                         River Siene    7980350@N08
# 3                                Notre Dame Cathedral    7980350@N08
# 4                           Notre Dame After the Fire    7980350@N08
# 5                      La Seine au Pont de Courbevoie   18205690@N02
# 6   Réflexion, le pont des arts à l'aube en novemb...  138486769@N02
# 7                                Notre Dame Cathedral    7980350@N08
# 8                             Stained Glass Cathedral    7980350@N08
# 9                                     Above the Altar    7980350@N08
# 10                         Crowds Taking in the Scene    7980350@N08

# %% [markdown]
# # Extra Stuff

# %%
#this method finds all photos associated with a user and attempts to find the geodata
def toymethod():
    user = flickr_api.Person.findByUserName("tomquirkphoto")
    photos = user.getPhotos()
    for photo in photos:
        print(flickr.photos.geo.getLocation(photo_id = photo["id"]))
